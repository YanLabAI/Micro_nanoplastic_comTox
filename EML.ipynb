# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor  
from sklearn.linear_model import LinearRegression  
from xgboost import XGBRegressor 
from sklearn.linear_model import LinearRegression  
from sklearn.model_selection import cross_val_score,train_test_split,cross_val_predict
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,log_loss, accuracy_score
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm 
 
data = pd.read_excel(r'd:\Desktop\1222\1225复合毒性数据.xlsx')

newdata = pd.get_dummies(data)
pd.DataFrame(newdata)

x = newdata.drop('Survival(%)',axis=1)
y = newdata['Survival(%)']

x.columns = x.columns.astype(str)
x = StandardScaler().fit_transform(x)
x = pd.DataFrame(x)

# %%
# 使用最佳参数初始化基础学习器  
best_rf = RandomForestRegressor(n_estimators=85, max_depth=19, random_state=55)  
best_gb = GradientBoostingRegressor(n_estimators=199, random_state=138, max_depth=7)  
best_xgb = XGBRegressor(n_estimators=100, learning_rate=0.3, max_depth=6, random_state=60, gamma=0)  

# 定义基础学习器  
estimators = [  
    ('rf', best_rf),  
    ('gbdt', best_gb),  
    ('xgb', best_xgb)  
]  

# 定义堆叠回归器  
stacking_reg = StackingRegressor(  
    estimators=estimators,  
    final_estimator=LinearRegression(),  
    cv=5  
)   

# 存储交叉验证和测试集结果  
results = []  

# 设置 random_state 循环  
for random_state in range(100):  # 你可以根据需求选择不同的循环范围  
    # 划分数据集  
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=random_state)  

    # 训练堆叠回归器  
    stacking_reg.fit(X_train, y_train)  

    # 计算交叉验证 R² 和 RMSE（使用训练集进行交叉验证）  
    cv_r2 = cross_val_score(stacking_reg, X_train, y_train, cv=5, scoring='r2')  
    cv_rmse = -cross_val_score(stacking_reg, X_train, y_train, cv=5, scoring='neg_root_mean_squared_error')  
    cv_mae = -cross_val_score(stacking_reg, X_train, y_train, cv=5, scoring='neg_mean_absolute_error')  

    # 在测试集上进行预测  
    y_pred = stacking_reg.predict(X_test)  

    # 计算测试集的 R² 和 RMSE  
    test_r2 = r2_score(y_test, y_pred)  
    test_rmse = mean_squared_error(y_test, y_pred, squared=False)  
    test_mae = mean_absolute_error(y_test, y_pred)  

    # 存储结果  
    results.append((random_state, cv_r2, cv_rmse, cv_mae, test_r2, test_rmse, test_mae))  

# 输出结果  
print("\n交叉验证和测试集结果：")  
for state, cv_r2, cv_rmse, cv_mae, test_r2, test_rmse, test_mae in results:  
    print(f'random_state={state}, 交叉验证 R²得分: {np.mean(cv_r2):.2f}, 交叉验证 RMSE: {np.mean(cv_rmse):.2f}, '  
          f'交叉验证 MAE: {np.mean(cv_mae):.2f}, 测试集 R²: {test_r2:.2f}, 测试集 RMSE: {test_rmse:.2f}, 测试集 MAE: {test_mae:.2f}')
# Out:
# 交叉验证和测试集结果：
# random_state=0, 交叉验证 R²得分: 0.77, 交叉验证 RMSE: 16.95, 交叉验证 MAE: 10.54, 测试集 R²: 0.82, 测试集 RMSE: 14.91, 测试集 MAE: 8.96
# random_state=1, 交叉验证 R²得分: 0.73, 交叉验证 RMSE: 18.25, 交叉验证 MAE: 11.37, 测试集 R²: 0.83, 测试集 RMSE: 14.40, 测试集 MAE: 10.49
# random_state=2, 交叉验证 R²得分: 0.73, 交叉验证 RMSE: 17.73, 交叉验证 MAE: 11.84, 测试集 R²: 0.77, 测试集 RMSE: 18.37, 测试集 MAE: 12.10
# random_state=3, 交叉验证 R²得分: 0.83, 交叉验证 RMSE: 14.75, 交叉验证 MAE: 9.95, 测试集 R²: 0.78, 测试集 RMSE: 15.83, 测试集 MAE: 8.16
# random_state=4, 交叉验证 R²得分: 0.81, 交叉验证 RMSE: 15.40, 交叉验证 MAE: 10.05, 测试集 R²: 0.75, 测试集 RMSE: 17.71, 测试集 MAE: 11.70
# random_state=5, 交叉验证 R²得分: 0.77, 交叉验证 RMSE: 16.69, 交叉验证 MAE: 10.90, 测试集 R²: 0.90, 测试集 RMSE: 11.47, 测试集 MAE: 7.93
# random_state=6, 交叉验证 R²得分: 0.80, 交叉验证 RMSE: 15.97, 交叉验证 MAE: 10.99, 测试集 R²: 0.88, 测试集 RMSE: 11.73, 测试集 MAE: 7.80
# random_state=7, 交叉验证 R²得分: 0.83, 交叉验证 RMSE: 14.47, 交叉验证 MAE: 9.95, 测试集 R²: 0.83, 测试集 RMSE: 14.49, 测试集 MAE: 9.14
# random_state=8, 交叉验证 R²得分: 0.75, 交叉验证 RMSE: 17.08, 交叉验证 MAE: 11.74, 测试集 R²: 0.93, 测试集 RMSE: 9.42, 测试集 MAE: 6.82
# random_state=9, 交叉验证 R²得分: 0.79, 交叉验证 RMSE: 16.07, 交叉验证 MAE: 10.67, 测试集 R²: 0.88, 测试集 RMSE: 12.94, 测试集 MAE: 8.64
# random_state=10, 交叉验证 R²得分: 0.79, 交叉验证 RMSE: 16.44, 交叉验证 MAE: 10.82, 测试集 R²: 0.84, 测试集 RMSE: 13.51, 测试集 MAE: 9.01
# random_state=11, 交叉验证 R²得分: 0.82, 交叉验证 RMSE: 15.10, 交叉验证 MAE: 10.60, 测试集 R²: 0.82, 测试集 RMSE: 14.73, 测试集 MAE: 9.33
# random_state=12, 交叉验证 R²得分: 0.78, 交叉验证 RMSE: 15.60, 交叉验证 MAE: 9.88, 测试集 R²: 0.88, 测试集 RMSE: 12.97, 测试集 MAE: 8.73
# random_state=13, 交叉验证 R²得分: 0.76, 交叉验证 RMSE: 16.99, 交叉验证 MAE: 10.86, 测试集 R²: 0.88, 测试集 RMSE: 12.56, 测试集 MAE: 9.09
# random_state=14, 交叉验证 R²得分: 0.71, 交叉验证 RMSE: 18.78, 交叉验证 MAE: 12.50, 测试集 R²: 0.80, 测试集 RMSE: 16.10, 测试集 MAE: 9.95
# random_state=15, 交叉验证 R²得分: 0.81, 交叉验证 RMSE: 15.18, 交叉验证 MAE: 10.00, 测试集 R²: 0.86, 测试集 RMSE: 13.35, 测试集 MAE: 8.20
# random_state=16, 交叉验证 R²得分: 0.81, 交叉验证 RMSE: 15.47, 交叉验证 MAE: 10.16, 测试集 R²: 0.81, 测试集 RMSE: 15.82, 测试集 MAE: 11.58
# random_state=17, 交叉验证 R²得分: 0.84, 交叉验证 RMSE: 14.55, 交叉验证 MAE: 9.55, 测试集 R²: 0.78, 测试集 RMSE: 14.89, 测试集 MAE: 9.36
# random_state=18, 交叉验证 R²得分: 0.78, 交叉验证 RMSE: 16.16, 交叉验证 MAE: 10.52, 测试集 R²: 0.83, 测试集 RMSE: 15.05, 测试集 MAE: 10.00
# random_state=19, 交叉验证 R²得分: 0.76, 交叉验证 RMSE: 16.73, 交叉验证 MAE: 10.75, 测试集 R²: 0.79, 测试集 RMSE: 17.49, 测试集 MAE: 10.74
# random_state=20, 交叉验证 R²得分: 0.81, 交叉验证 RMSE: 15.55, 交叉验证 MAE: 10.42, 测试集 R²: 0.87, 测试集 RMSE: 11.88, 测试集 MAE: 8.17
# random_state=21, 交叉验证 R²得分: 0.82, 交叉验证 RMSE: 15.60, 交叉验证 MAE: 10.18, 测试集 R²: 0.86, 测试集 RMSE: 12.25, 测试集 MAE: 8.56
# random_state=22, 交叉验证 R²得分: 0.86, 交叉验证 RMSE: 13.61, 交叉验证 MAE: 9.02, 测试集 R²: 0.89, 测试集 RMSE: 11.53, 测试集 MAE: 7.67
# random_state=23, 交叉验证 R²得分: 0.85, 交叉验证 RMSE: 13.75, 交叉验证 MAE: 9.26, 测试集 R²: 0.76, 测试集 RMSE: 15.74, 测试集 MAE: 9.59
# random_state=24, 交叉验证 R²得分: 0.77, 交叉验证 RMSE: 17.03, 交叉验证 MAE: 11.12, 测试集 R²: 0.90, 测试集 RMSE: 11.25, 测试集 MAE: 6.70
# random_state=25, 交叉验证 R²得分: 0.81, 交叉验证 RMSE: 15.30, 交叉验证 MAE: 10.26, 测试集 R²: 0.87, 测试集 RMSE: 13.11, 测试集 MAE: 8.18
# random_state=26, 交叉验证 R²得分: 0.71, 交叉验证 RMSE: 18.37, 交叉验证 MAE: 12.02, 测试集 R²: 0.92, 测试集 RMSE: 11.17, 测试集 MAE: 7.32
# random_state=27, 交叉验证 R²得分: 0.79, 交叉验证 RMSE: 15.75, 交叉验证 MAE: 10.61, 测试集 R²: 0.95, 测试集 RMSE: 8.13, 测试集 MAE: 5.73
# random_state=28, 交叉验证 R²得分: 0.84, 交叉验证 RMSE: 14.08, 交叉验证 MAE: 9.51, 测试集 R²: 0.91, 测试集 RMSE: 10.68, 测试集 MAE: 8.03
# random_state=29, 交叉验证 R²得分: 0.86, 交叉验证 RMSE: 13.92, 交叉验证 MAE: 9.52, 测试集 R²: 0.79, 测试集 RMSE: 14.23, 测试集 MAE: 9.50
# random_state=30, 交叉验证 R²得分: 0.75, 交叉验证 RMSE: 17.17, 交叉验证 MAE: 11.33, 测试集 R²: 0.91, 测试集 RMSE: 11.00, 测试集 MAE: 7.05
# random_state=31, 交叉验证 R²得分: 0.81, 交叉验证 RMSE: 15.70, 交叉验证 MAE: 9.73, 测试集 R²: 0.71, 测试集 RMSE: 17.45, 测试集 MAE: 11.40
# random_state=32, 交叉验证 R²得分: 0.79, 交叉验证 RMSE: 15.35, 交叉验证 MAE: 10.45, 测试集 R²: 0.75, 测试集 RMSE: 16.72, 测试集 MAE: 9.89
# random_state=33, 交叉验证 R²得分: 0.83, 交叉验证 RMSE: 14.27, 交叉验证 MAE: 9.47, 测试集 R²: 0.94, 测试集 RMSE: 8.47, 测试集 MAE: 6.04
# random_state=34, 交叉验证 R²得分: 0.79, 交叉验证 RMSE: 15.18, 交叉验证 MAE: 10.01, 测试集 R²: 0.92, 测试集 RMSE: 10.71, 测试集 MAE: 7.20
# random_state=35, 交叉验证 R²得分: 0.80, 交叉验证 RMSE: 14.94, 交叉验证 MAE: 9.96, 测试集 R²: 0.89, 测试集 RMSE: 12.81, 测试集 MAE: 8.45
# random_state=36, 交叉验证 R²得分: 0.78, 交叉验证 RMSE: 16.14, 交叉验证 MAE: 10.88, 测试集 R²: 0.90, 测试集 RMSE: 11.81, 测试集 MAE: 7.41
# random_state=37, 交叉验证 R²得分: 0.73, 交叉验证 RMSE: 18.27, 交叉验证 MAE: 11.97, 测试集 R²: 0.90, 测试集 RMSE: 11.26, 测试集 MAE: 7.45
# random_state=38, 交叉验证 R²得分: 0.77, 交叉验证 RMSE: 16.70, 交叉验证 MAE: 10.90, 测试集 R²: 0.85, 测试集 RMSE: 13.17, 测试集 MAE: 8.32
# random_state=39, 交叉验证 R²得分: 0.80, 交叉验证 RMSE: 15.47, 交叉验证 MAE: 10.37, 测试集 R²: 0.86, 测试集 RMSE: 13.30, 测试集 MAE: 8.20
# random_state=40, 交叉验证 R²得分: 0.81, 交叉验证 RMSE: 14.89, 交叉验证 MAE: 9.51, 测试集 R²: 0.88, 测试集 RMSE: 13.19, 测试集 MAE: 9.07
# random_state=41, 交叉验证 R²得分: 0.76, 交叉验证 RMSE: 16.45, 交叉验证 MAE: 10.77, 测试集 R²: 0.91, 测试集 RMSE: 11.16, 测试集 MAE: 6.89
# random_state=42, 交叉验证 R²得分: 0.77, 交叉验证 RMSE: 16.99, 交叉验证 MAE: 11.26, 测试集 R²: 0.90, 测试集 RMSE: 11.63, 测试集 MAE: 7.65
# random_state=43, 交叉验证 R²得分: 0.79, 交叉验证 RMSE: 15.80, 交叉验证 MAE: 10.16, 测试集 R²: 0.83, 测试集 RMSE: 15.25, 测试集 MAE: 8.93
# random_state=44, 交叉验证 R²得分: 0.80, 交叉验证 RMSE: 15.59, 交叉验证 MAE: 10.39, 测试集 R²: 0.76, 测试集 RMSE: 16.29, 测试集 MAE: 9.10
# random_state=45, 交叉验证 R²得分: 0.80, 交叉验证 RMSE: 16.20, 交叉验证 MAE: 10.53, 测试集 R²: 0.91, 测试集 RMSE: 9.64, 测试集 MAE: 5.98
# random_state=46, 交叉验证 R²得分: 0.78, 交叉验证 RMSE: 15.74, 交叉验证 MAE: 10.45, 测试集 R²: 0.86, 测试集 RMSE: 14.37, 测试集 MAE: 8.59
# random_state=47, 交叉验证 R²得分: 0.76, 交叉验证 RMSE: 16.93, 交叉验证 MAE: 10.84, 测试集 R²: 0.83, 测试集 RMSE: 16.07, 测试集 MAE: 9.99
# random_state=48, 交叉验证 R²得分: 0.81, 交叉验证 RMSE: 14.81, 交叉验证 MAE: 9.57, 测试集 R²: 0.78, 测试集 RMSE: 17.83, 测试集 MAE: 10.46
# random_state=49, 交叉验证 R²得分: 0.76, 交叉验证 RMSE: 17.15, 交叉验证 MAE: 10.93, 测试集 R²: 0.89, 测试集 RMSE: 11.77, 测试集 MAE: 8.03
